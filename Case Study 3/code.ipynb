# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# -------------------------
# Parameters
# -------------------------

img_size = 224
batch_size = 32
epochs = 15

# -------------------------
# Data Augmentation
# -------------------------

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    "dataset/train",
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    "dataset/train",
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# -------------------------
# CNN Model Architecture
# -------------------------

model = models.Sequential()

# Block 1
model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(224,224,3)))
model.add(layers.Conv2D(32,(3,3),activation='relu'))
model.add(layers.MaxPooling2D(2,2))

# Block 2
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D(2,2))

# Block 3
model.add(layers.Conv2D(128,(3,3),activation='relu'))
model.add(layers.MaxPooling2D(2,2))

# Flatten
model.add(layers.Flatten())

# Dense Layers
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dropout(0.5))

# Output Layer
model.add(layers.Dense(2,activation='softmax'))

# -------------------------
# Compile Model
# -------------------------

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# -------------------------
# Early Stopping
# -------------------------

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# -------------------------
# Training
# -------------------------

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator,
    callbacks=[early_stop]
)

# -------------------------
# Evaluation
# -------------------------

loss, accuracy = model.evaluate(val_generator)

print("Validation Accuracy:", accuracy)

# -------------------------
# Accuracy Graph
# -------------------------

plt.figure(figsize=(8,5))

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")

plt.legend()
plt.show()

# -------------------------
# Loss Graph
# -------------------------

plt.figure(figsize=(8,5))

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")

plt.legend()
plt.show()
# Out:
# Found 203 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.
# /opt/anaconda3/envs/antigravity_dl/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-03-18 02:01:04.801099: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2026-03-18 02:01:04.801248: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-18 02:01:04.801263: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-18 02:01:04.801650: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-18 02:01:04.801667: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 220, 220, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 110, 110, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 108, 108, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 106, 106, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 53, 53, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 51, 51, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 25, 25, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 80000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    20,480,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,620,194 (78.66 MB)
#  Trainable params: 20,620,194 (78.66 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 2026-03-18 02:01:06.979934: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 0.5000 - loss: 0.6986
# 2/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.5156 - loss: 0.6937
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.5382 - loss: 0.6780
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 1s 348ms/step - accuracy: 0.5462 - loss: 0.6712
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.5607 - loss: 0.6586
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.5657 - loss: 0.6557
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.5742 - loss: 0.6517
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 373ms/step - accuracy: 0.6256 - loss: 0.6279 - val_accuracy: 0.7200 - val_loss: 0.5157
# Epoch 2/15
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 1s 310ms/step - accuracy: 0.8438 - loss: 0.4601
# 2/7 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8359 - loss: 0.4686
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8177 - loss: 0.4884
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7988 - loss: 0.5030
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7858 - loss: 0.5131
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7699 - loss: 0.5260
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7563 - loss: 0.5393
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.6749 - loss: 0.6187 - val_accuracy: 0.7200 - val_loss: 0.6031
# Epoch 3/15
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step - accuracy: 0.6875 - loss: 0.6255
# 2/7 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6641 - loss: 0.6308
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6580 - loss: 0.6375
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6536 - loss: 0.6475
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6517 - loss: 0.6484
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6550 - loss: 0.6448
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6579 - loss: 0.6419
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - accuracy: 0.6749 - loss: 0.6247 - val_accuracy: 0.6800 - val_loss: 0.5469
# Epoch 4/15
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7273 - loss: 0.5988
# 2/7 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.7241 - loss: 0.5695
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7050 - loss: 0.5769
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6876 - loss: 0.5892
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.6839 - loss: 0.5886
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.6878 - loss: 0.5848
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.6923 - loss: 0.5814
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.7192 - loss: 0.5610 - val_accuracy: 0.7800 - val_loss: 0.5110
# Epoch 5/15
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 1s 310ms/step - accuracy: 0.7188 - loss: 0.6206
# 2/7 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6953 - loss: 0.6296
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7031 - loss: 0.6105
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7129 - loss: 0.5960
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7185 - loss: 0.5866
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7206 - loss: 0.5803
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7225 - loss: 0.5756
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.7340 - loss: 0.5475 - val_accuracy: 0.7600 - val_loss: 0.5402
# Epoch 6/15
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6364 - loss: 0.5147
# 2/7 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 0.6786 - loss: 0.5122
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.6835 - loss: 0.5363
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.6926 - loss: 0.5418
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6907 - loss: 0.5504
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6916 - loss: 0.5527
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.6927 - loss: 0.5547
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - accuracy: 0.6995 - loss: 0.5663 - val_accuracy: 0.7600 - val_loss: 0.5099
# Epoch 7/15
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step - accuracy: 0.8125 - loss: 0.4736
# 2/7 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.8203 - loss: 0.4622
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8269 - loss: 0.4538
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8094 - loss: 0.4676
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7957 - loss: 0.4788
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7918 - loss: 0.4823
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7870 - loss: 0.4864
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.7586 - loss: 0.5111 - val_accuracy: 0.7200 - val_loss: 0.5168
# Epoch 8/15
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - accuracy: 0.7812 - loss: 0.4524
# 2/7 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7734 - loss: 0.4672
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7645 - loss: 0.4791
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7673 - loss: 0.4794
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7692 - loss: 0.4795
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.7668 - loss: 0.4816
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7670 - loss: 0.4824
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 0.7685 - loss: 0.4873 - val_accuracy: 0.7200 - val_loss: 0.5633
# Epoch 9/15
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 2s 355ms/step - accuracy: 0.8125 - loss: 0.4830
# 2/7 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7812 - loss: 0.5103
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7708 - loss: 0.5144
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7695 - loss: 0.5129
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7669 - loss: 0.5136
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7632 - loss: 0.5151
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7611 - loss: 0.5175
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.7488 - loss: 0.5318 - val_accuracy: 0.7200 - val_loss: 0.5967
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6562 - loss: 0.6538
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7000 - loss: 0.5881
# Validation Accuracy: 0.699999988079071
